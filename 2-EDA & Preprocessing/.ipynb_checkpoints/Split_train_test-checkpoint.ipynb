# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv("../1-Data/heart.csv")
X = df.drop('HeartDisease', axis=1)
y = df['HeartDisease']

# %%
df_train, df_test = train_test_split(
    df, 
    test_size=0.2, 
    random_state=42, 
    stratify=df['HeartDisease']
)

df_train.to_csv(f'{../1-Data}/train_data.csv', index = False)
df_test.to_csv(f'{../1-Data}/train_data.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 8
#       1 df_train, df_test = train_test_split(
#       2     df,
#       3     test_size=0.2,
#       4     random_state=42,
#       5     stratify=df['HeartDisease']
#       6 )
# ----> 8 df_train.to_csv(f'{1-Data}/train_data.csv', index = False)
#       9 df_test.to_csv(f'{1-Data}/train_data.csv', index=False)
#
# NameError: name 'Data' is not defined
