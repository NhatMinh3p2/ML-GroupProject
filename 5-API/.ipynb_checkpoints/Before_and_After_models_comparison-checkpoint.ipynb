# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report


train = pd.read_csv("../1-Data/train_processed.csv")
test = pd.read_csv("../1-Data/test_processed.csv")

# Baseline features (Before)
X_train_before = train.drop(columns=["HeartDisease"])
y_train = train["HeartDisease"]
X_test_before = test.drop(columns=["HeartDisease"])
y_test = test["HeartDisease"]

# 2. Train the Baseline Model (Before)
rf_before = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
rf_before.fit(X_train_before, y_train)
y_pred_before = rf_before.predict(X_test_before)
acc_before = accuracy_score(y_test, y_pred_before)

# 3. Implement the LLM Feature Suggestion (After)
X_train_after = X_train_before.copy()
X_test_after = X_test_before.copy()


X_train_after["MaxHR_x_ExerciseAngina"] = X_train_after["MaxHR"] * X_train_after["ExerciseAngina"]
X_test_after["MaxHR_x_ExerciseAngina"] = X_test_after["MaxHR"] * X_test_after["ExerciseAngina"]

# 4. (After)
rf_after = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42)
rf_after.fit(X_after := X_train_after, y_train)
y_pred_after = rf_after.predict(X_test_after)
acc_after = accuracy_score(y_test, y_pred_after)


print("\n===============================================")
print("          CONTROLLED EXPERIMENT RESULTS        ")
print("===============================================")
print(f"Accuracy BEFORE LLM Feature: {acc_before * 100:.2f}%")
print(f"Accuracy AFTER LLM Feature:  {acc_after * 100:.2f}%")
print(f"Absolute Net Performance Gain: {((acc_after - acc_before) * 100):+.2f}%")
print("===============================================")

print("\nDetailed Report AFTER Feature Engineering:")
print(classification_report(y_test, y_pred_after, target_names=["Normal", "Heart Disease"]))
# Out:
# ...
#           CONTROLLED EXPERIMENT RESULTS
# ...
# Accuracy BEFORE LLM Feature: 90.22%
# Accuracy AFTER LLM Feature:  89.13%
# Absolute Net Performance Gain: -1.09%
# ...
#
# Detailed Report AFTER Feature Engineering:
#                precision    recall  f1-score   support
#
#        Normal       0.90      0.85      0.88        82
# Heart Disease       0.89      0.92      0.90       102
#
#      accuracy                           0.89       184
#     macro avg       0.89      0.89      0.89       184
#  weighted avg       0.89      0.89      0.89       184

# %% [raw]
# The feature combined MaxHR and ExerciseAngina mathematically (MaxHR * ExerciseAngina). While this makes sense in a medical textbook, it introduced a structural issue into a Random Forest model called Feature Smearing / Noise Addition.
#
# How Random Forest handles split choices: A decision tree splits data based on crisp cutoffs (e.g., Is MaxHR > 140?).
#
# The structural flaw: For anyone who answered No to exercise angina (ExerciseAngina = 0), their new feature value instantly became 0. For anyone who answered Yes, their feature value became their actual heart rate (e.g., 150).
#
# The consequence: This created a massive, artificial cluster of values at exactly 0 for healthy patients, throwing off the tree's gini impurity calculations. Instead of discovering a subtle pattern, the model got confused by the mathematical distortion and lost its ability to classify a few borderline cases accurately.
