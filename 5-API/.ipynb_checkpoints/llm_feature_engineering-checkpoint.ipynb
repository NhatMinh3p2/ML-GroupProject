# %%
import os
from groq import Groq


client = Groq(api_key="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")


prompt_content = """
You are a Medical AI Feature Engineering Assistant. We are building a machine learning model to predict Heart Disease using the UCI Heart Disease dataset.

Our current processed features are:
- Age (numerical)
- Sex (binary: 0=F, 1=M)
- RestingBP (numerical)
- Cholesterol (numerical)
- FastingBS (binary: 0 or 1)
- MaxHR (numerical)
- ExerciseAngina (binary: 0=No, 1=Yes)
- Oldpeak (numerical, ST depression induced by exercise relative to rest)
- ST_Slope (ordinal: 0=Down, 1=Flat, 2=Up)
- ChestPainType features (One-hot encoded: ATA, NAP, TA)
- RestingECG features (One-hot encoded: Normal, ST)

Please suggest 3 clinically relevant engineered features (combinations, ratios, or interactions of our existing columns) that could help a non-linear machine learning model better identify cardiovascular risk patterns. Keep your suggestions simple and explain the medical intuition behind them.
"""

print("Querying the LLM for Feature Engineering Suggestions...")


completion = client.chat.completions.create(
    model="llama-3.1-8b-instant", 
    messages=[
        {"role": "user", "content": prompt_content}
    ]
)

print("\n=== LLM SUGGESTIONS ===")
print(completion.choices[0].message.content)
# Out:
# Querying the LLM for Feature Engineering Suggestions...
#
# === LLM SUGGESTIONS ===
# As a Medical AI Feature Engineering Assistant, I would suggest the following three clinically relevant engineered features:
#
# 1. **Cholesterol-to-Oldpeak Ratio (C/OR)**:
#
# Feature calculation: `C/OR = Cholesterol / Oldpeak`
#
# Medical intuition: This feature captures the relationship between cholesterol levels and the ST depression response to exercise, which is indicative of cardiovascular stress. A higher C/OR may suggest a higher risk of heart disease, as individuals with higher cholesterol levels and minimal ST depression may be more susceptible to cardiovascular events.
#
# 2. **BP-Cholesterol Interaction (BCI)**:
#
# Feature calculation: `BCI = RestingBP * Cholesterol`
#
# Medical intuition: This feature examines the interaction between resting blood pressure and cholesterol levels, which are both significant risk factors for heart disease. A higher BCI may indicate an increased risk of cardiovascular events due to the compounded effects of elevated blood pressure and cholesterol levels.
#
# 3. **Age-Sex-ChestPainType interaction (ASCT)**:
#
# Feature calculation: `ASCT = Age * Sex * ChestPainType_TA`
#
# Medical intuition: This feature considers the interaction between age, sex, and chest pain type, which can be indicative of underlying cardiovascular pathology. For instance, older males with Type A chest pain type may be at higher risk of heart disease due to the additive effects of aging, male hormone effects, and the stress of Type A behavior.
#
# These engineered features are designed to capture non-linear relationships between the existing columns, which may enhance the predictive capabilities of the machine learning model. However, it is essential to evaluate the performance of these features in conjunction with domain expertise to ensure clinical relevance and interpretability.
